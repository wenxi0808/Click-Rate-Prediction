# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import SGDClassifier
from xgboost import XGBClassifier
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import log_loss
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, log_loss, confusion_matrix, roc_curve, auc, accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import RMSprop
from keras.layers import Dense, Dropout, BatchNormalization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
# Load your scaled data
df_train = pd.read_csv('/content/drive/MyDrive/AI ML Project/Train_data_Max.csv')
df_val = pd.read_csv('/content/drive/MyDrive/AI ML Project/Val_data_Max')

# Prepare the datasets
X_train = df_train.drop('click', axis=1)
y_train = df_train['click']
X_val = df_val.drop('click', axis=1)
y_val = df_val['click']

# %%
# Define the neural network model
model = Sequential([
    Dense(512, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.1),
    Dense(1, activation='sigmoid')
])

# Define the checkpoint callback
checkpoint = ModelCheckpoint(
    '/content/drive/MyDrive/AI ML Project/model_checkpoint.h5',
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max',
    save_freq='epoch'
)

# Define EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=10,
    verbose=1,
    restore_best_weights=True
)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=200,
    batch_size=1024,
    callbacks=[checkpoint, early_stopping]
)

# Function to calculate and print performance metrics and save classification report
def evaluate_performance(X, y, dataset_name):
    # Predict probabilities and classes
    y_pred_probs = model.predict(X)
    y_pred = (y_pred_probs > 0.5).astype(int)

    # Log Loss
    log_loss_value = log_loss(y, y_pred_probs)

    # Classification Report, F1 Score, and Saving Report
    report = classification_report(y, y_pred, output_dict=True)
    f1_score = report['weighted avg']['f1-score']
    report_df = pd.DataFrame(report).transpose()
    report_df.to_csv(f'{dataset_name.lower()}_classification_report.csv')

    # Confusion Matrix
    cm = confusion_matrix(y, y_pred)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    # Accuracy
    accuracy = accuracy_score(y, y_pred)

    # ROC Curve and AUC
    fpr, tpr, thresholds = roc_curve(y, y_pred_probs)
    roc_auc = auc(fpr, tpr)

    # Print Metrics
    print(f"Performance on {dataset_name} Dataset:")
    print(f"Accuracy: {accuracy}")
    print(f"Log Loss: {log_loss_value}")
    print(f"F1 Score: {f1_score}")
    print("Classification Report:")
    print(report_df)
    print("Confusion Matrix:")
    print(cm)
    print("Normalized Confusion Matrix:")
    print(cm_normalized)

    # Plot ROC Curve
    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange', lw=lw, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Receiver Operating Characteristic ({dataset_name})')
    plt.legend(loc="lower right")
    plt.show()

# Evaluate Performance on Training and Validation Datasets
evaluate_performance(X_train, y_train, "Training")
evaluate_performance(X_val, y_val, "Validation")
# Out:
# Epoch 1/200
# 8493/8493 [==============================] - ETA: 0s - loss: 0.6291 - accuracy: 0.6397
# Epoch 1: val_accuracy improved from -inf to 0.65597, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 68s 7ms/step - loss: 0.6291 - accuracy: 0.6397 - val_loss: 0.6146 - val_accuracy: 0.6560
# Epoch 2/200
#    9/8493 [..............................] - ETA: 58s - loss: 0.6189 - accuracy: 0.6494
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 8488/8493 [============================>.] - ETA: 0s - loss: 0.6172 - accuracy: 0.6540
# Epoch 2: val_accuracy improved from 0.65597 to 0.66100, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6172 - accuracy: 0.6540 - val_loss: 0.6097 - val_accuracy: 0.6610
# Epoch 3/200
# 8488/8493 [============================>.] - ETA: 0s - loss: 0.6140 - accuracy: 0.6576
# Epoch 3: val_accuracy improved from 0.66100 to 0.66447, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6140 - accuracy: 0.6576 - val_loss: 0.6070 - val_accuracy: 0.6645
# Epoch 4/200
# 8493/8493 [==============================] - ETA: 0s - loss: 0.6121 - accuracy: 0.6597
# Epoch 4: val_accuracy improved from 0.66447 to 0.66625, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6121 - accuracy: 0.6597 - val_loss: 0.6052 - val_accuracy: 0.6662
# Epoch 5/200
# 8488/8493 [============================>.] - ETA: 0s - loss: 0.6109 - accuracy: 0.6609
# Epoch 5: val_accuracy improved from 0.66625 to 0.66733, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6109 - accuracy: 0.6609 - val_loss: 0.6046 - val_accuracy: 0.6673
# Epoch 6/200
# 8487/8493 [============================>.] - ETA: 0s - loss: 0.6097 - accuracy: 0.6619
# Epoch 6: val_accuracy improved from 0.66733 to 0.66779, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6097 - accuracy: 0.6619 - val_loss: 0.6031 - val_accuracy: 0.6678
# Epoch 7/200
# 8486/8493 [============================>.] - ETA: 0s - loss: 0.6091 - accuracy: 0.6625
# Epoch 7: val_accuracy improved from 0.66779 to 0.66885, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6091 - accuracy: 0.6625 - val_loss: 0.6026 - val_accuracy: 0.6689
# Epoch 8/200
# 8492/8493 [============================>.] - ETA: 0s - loss: 0.6086 - accuracy: 0.6629
# Epoch 8: val_accuracy improved from 0.66885 to 0.66896, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6086 - accuracy: 0.6629 - val_loss: 0.6024 - val_accuracy: 0.6690
# Epoch 9/200
# 8491/8493 [============================>.] - ETA: 0s - loss: 0.6080 - accuracy: 0.6636
# Epoch 9: val_accuracy improved from 0.66896 to 0.66945, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6080 - accuracy: 0.6636 - val_loss: 0.6017 - val_accuracy: 0.6694
# Epoch 10/200
# 8492/8493 [============================>.] - ETA: 0s - loss: 0.6075 - accuracy: 0.6641
# Epoch 10: val_accuracy improved from 0.66945 to 0.67023, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6075 - accuracy: 0.6641 - val_loss: 0.6011 - val_accuracy: 0.6702
# Epoch 11/200
# 8491/8493 [============================>.] - ETA: 0s - loss: 0.6071 - accuracy: 0.6644
# Epoch 11: val_accuracy improved from 0.67023 to 0.67059, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6071 - accuracy: 0.6644 - val_loss: 0.6010 - val_accuracy: 0.6706
# Epoch 12/200
# 8491/8493 [============================>.] - ETA: 0s - loss: 0.6068 - accuracy: 0.6648
# Epoch 12: val_accuracy improved from 0.67059 to 0.67121, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6068 - accuracy: 0.6648 - val_loss: 0.6002 - val_accuracy: 0.6712
# Epoch 13/200
# 8492/8493 [============================>.] - ETA: 0s - loss: 0.6065 - accuracy: 0.6652
# Epoch 13: val_accuracy did not improve from 0.67121
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6065 - accuracy: 0.6652 - val_loss: 0.6003 - val_accuracy: 0.6707
# Epoch 14/200
# 8491/8493 [============================>.] - ETA: 0s - loss: 0.6061 - accuracy: 0.6656
# Epoch 14: val_accuracy improved from 0.67121 to 0.67209, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6061 - accuracy: 0.6656 - val_loss: 0.5997 - val_accuracy: 0.6721
# Epoch 15/200
# 8490/8493 [============================>.] - ETA: 0s - loss: 0.6059 - accuracy: 0.6660
# Epoch 15: val_accuracy did not improve from 0.67209
# 8493/8493 [==============================] - 58s 7ms/step - loss: 0.6059 - accuracy: 0.6660 - val_loss: 0.5999 - val_accuracy: 0.6716
# Epoch 16/200
# 8491/8493 [============================>.] - ETA: 0s - loss: 0.6057 - accuracy: 0.6661
# Epoch 16: val_accuracy improved from 0.67209 to 0.67223, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6057 - accuracy: 0.6661 - val_loss: 0.5993 - val_accuracy: 0.6722
# Epoch 17/200
# 8488/8493 [============================>.] - ETA: 0s - loss: 0.6054 - accuracy: 0.6663
# Epoch 17: val_accuracy improved from 0.67223 to 0.67279, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6054 - accuracy: 0.6663 - val_loss: 0.5993 - val_accuracy: 0.6728
# Epoch 18/200
# 8488/8493 [============================>.] - ETA: 0s - loss: 0.6052 - accuracy: 0.6667
# Epoch 18: val_accuracy did not improve from 0.67279
# 8493/8493 [==============================] - 58s 7ms/step - loss: 0.6052 - accuracy: 0.6667 - val_loss: 0.5993 - val_accuracy: 0.6726
# Epoch 19/200
# 8487/8493 [============================>.] - ETA: 0s - loss: 0.6050 - accuracy: 0.6668
# Epoch 19: val_accuracy improved from 0.67279 to 0.67281, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6050 - accuracy: 0.6668 - val_loss: 0.5990 - val_accuracy: 0.6728
# Epoch 20/200
# 8487/8493 [============================>.] - ETA: 0s - loss: 0.6048 - accuracy: 0.6670
# Epoch 20: val_accuracy improved from 0.67281 to 0.67312, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6048 - accuracy: 0.6670 - val_loss: 0.5985 - val_accuracy: 0.6731
# Epoch 21/200
# 8487/8493 [============================>.] - ETA: 0s - loss: 0.6047 - accuracy: 0.6672
# Epoch 21: val_accuracy improved from 0.67312 to 0.67331, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6047 - accuracy: 0.6672 - val_loss: 0.5985 - val_accuracy: 0.6733
# Epoch 22/200
# 8490/8493 [============================>.] - ETA: 0s - loss: 0.6046 - accuracy: 0.6674
# Epoch 22: val_accuracy did not improve from 0.67331
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6046 - accuracy: 0.6674 - val_loss: 0.5987 - val_accuracy: 0.6731
# Epoch 23/200
# 8487/8493 [============================>.] - ETA: 0s - loss: 0.6044 - accuracy: 0.6675
# Epoch 23: val_accuracy improved from 0.67331 to 0.67380, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6044 - accuracy: 0.6675 - val_loss: 0.5983 - val_accuracy: 0.6738
# Epoch 24/200
# 8489/8493 [============================>.] - ETA: 0s - loss: 0.6043 - accuracy: 0.6678
# Epoch 24: val_accuracy did not improve from 0.67380
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6043 - accuracy: 0.6678 - val_loss: 0.5983 - val_accuracy: 0.6735
# Epoch 25/200
# 8486/8493 [============================>.] - ETA: 0s - loss: 0.6041 - accuracy: 0.6680
# Epoch 25: val_accuracy improved from 0.67380 to 0.67421, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6041 - accuracy: 0.6680 - val_loss: 0.5978 - val_accuracy: 0.6742
# Epoch 26/200
# 8488/8493 [============================>.] - ETA: 0s - loss: 0.6040 - accuracy: 0.6680
# Epoch 26: val_accuracy did not improve from 0.67421
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6040 - accuracy: 0.6680 - val_loss: 0.5979 - val_accuracy: 0.6739
# Epoch 27/200
# 8489/8493 [============================>.] - ETA: 0s - loss: 0.6038 - accuracy: 0.6681
# Epoch 27: val_accuracy improved from 0.67421 to 0.67439, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6039 - accuracy: 0.6681 - val_loss: 0.5978 - val_accuracy: 0.6744
# Epoch 28/200
# 8493/8493 [==============================] - ETA: 0s - loss: 0.6037 - accuracy: 0.6683
# Epoch 28: val_accuracy did not improve from 0.67439
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6037 - accuracy: 0.6683 - val_loss: 0.5978 - val_accuracy: 0.6738
# Epoch 29/200
# 8490/8493 [============================>.] - ETA: 0s - loss: 0.6036 - accuracy: 0.6683
# Epoch 29: val_accuracy improved from 0.67439 to 0.67452, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6036 - accuracy: 0.6683 - val_loss: 0.5973 - val_accuracy: 0.6745
# Epoch 30/200
# 8488/8493 [============================>.] - ETA: 0s - loss: 0.6035 - accuracy: 0.6686
# Epoch 30: val_accuracy did not improve from 0.67452
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6035 - accuracy: 0.6686 - val_loss: 0.5974 - val_accuracy: 0.6742
# Epoch 31/200
# 8490/8493 [============================>.] - ETA: 0s - loss: 0.6034 - accuracy: 0.6687
# Epoch 31: val_accuracy improved from 0.67452 to 0.67468, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6035 - accuracy: 0.6687 - val_loss: 0.5971 - val_accuracy: 0.6747
# Epoch 32/200
# 8492/8493 [============================>.] - ETA: 0s - loss: 0.6033 - accuracy: 0.6686
# Epoch 32: val_accuracy did not improve from 0.67468
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6033 - accuracy: 0.6686 - val_loss: 0.5972 - val_accuracy: 0.6745
# Epoch 33/200
# 8487/8493 [============================>.] - ETA: 0s - loss: 0.6033 - accuracy: 0.6688
# Epoch 33: val_accuracy did not improve from 0.67468
# 8493/8493 [==============================] - 60s 7ms/step - loss: 0.6033 - accuracy: 0.6688 - val_loss: 0.5977 - val_accuracy: 0.6742
# Epoch 34/200
# 8488/8493 [============================>.] - ETA: 0s - loss: 0.6031 - accuracy: 0.6689
# Epoch 34: val_accuracy improved from 0.67468 to 0.67502, saving model to /content/drive/MyDrive/AI ML Project/model_checkpoint.h5
# 8493/8493 [==============================] - 59s 7ms/step - loss: 0.6031 - accuracy: 0.6689 - val_loss: 0.5970 - val_accuracy: 0.6750
# Epoch 35/200
# 8491/8493 [============================>.] - ETA: 0s - loss: 0.6031 - accuracy: 0.6690
# Epoch 35: val_accuracy did not improve from 0.67502
# Restoring model weights from the end of the best epoch: 25.
# 8493/8493 [==============================] - 58s 7ms/step - loss: 0.6031 - accuracy: 0.6690 - val_loss: 0.5969 - val_accuracy: 0.6749
# Epoch 35: early stopping
# 271774/271774 [==============================] - 478s 2ms/step
# Performance on Training Dataset:
# Accuracy: 0.6743287128785733
# Log Loss: 0.5972806604862227
# F1 Score: 0.6735434924020764
# Classification Report:
#               precision    recall  f1-score       support
# 0              0.693339  0.625273  0.657549  4.348781e+06
# 1              0.658715  0.723393  0.689541  4.347982e+06
# accuracy       0.674329  0.674329  0.674329  6.743287e-01
# macro avg      0.676027  0.674333  0.673545  8.696763e+06
# weighted avg   0.676028  0.674329  0.673543  8.696763e+06
# Confusion Matrix:
# [[2719177 1629604]
#  [1202682 3145300]]
# Normalized Confusion Matrix:
# [[0.62527338 0.37472662]
#  [0.27660694 0.72339306]]
# 67944/67944 [==============================] - 122s 2ms/step
# Performance on Validation Dataset:
# Accuracy: 0.674211235351448
# Log Loss: 0.5977776209931691
# F1 Score: 0.6734402276089162
# Classification Report:
#               precision    recall  f1-score       support
# 0              0.693015  0.625609  0.657589  1.087196e+06
# 1              0.658739  0.722822  0.689294  1.086995e+06
# accuracy       0.674211  0.674211  0.674211  6.742112e-01
# macro avg      0.675877  0.674216  0.673442  2.174191e+06
# weighted avg   0.675878  0.674211  0.673440  2.174191e+06
# Confusion Matrix:
# [[680160 407036]
#  [301291 785704]]
# Normalized Confusion Matrix:
# [[0.62560937 0.37439063]
#  [0.27717791 0.72282209]]
